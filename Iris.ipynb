# %%
import pandas as pd

df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import seaborn as sns
#sns.set_style('whitegrid')
#sns.pairplot(df,hue='Species')
sns.FacetGrid(df,hue='Species',size=5).map(sns.distplot,'PetalLengthCm').add_legend();

# %%
import matplotlib.pyplot as plt

plt.plot(df['SepalLengthCm'],df['SepalWidthCm'],'ro',markersize=3)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.violinplot(x='Species',y='PetalLengthCm',data=df)
plt.plot()
# Out:
# []

# %%
sns.pairplot(df,hue='Species')

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,test_size=0.3,random_state=3)

# %%
df2=train[train['Species']!='Iris-setosa']

# %%
plt.figure(figsize=(20,10))
#plt.plot(train.SepalLengthCm[(train['Species']=='Iris-setosa')],train.SepalWidthCm[(train['Species']=='Iris-setosa')],'ro',markersize=10)
plt.plot(train.PetalLengthCm[(train['Species']=='Iris-setosa')],train.PetalWidthCm[(train['Species']=='Iris-setosa')],'ro',markersize=10)

#plt.plot(train.SepalLengthCm[(train['Species']=='Iris-versicolor')],train.SepalWidthCm[(train['Species']=='Iris-versicolor')],'bo',markersize=10)
plt.plot(train.PetalLengthCm[(train['Species']=='Iris-versicolor')],train.PetalWidthCm[(train['Species']=='Iris-versicolor')],'go',markersize=10)

#plt.plot(train.SepalLengthCm[(train['Species']=='Iris-virginica')],train.SepalWidthCm[(train['Species']=='Iris-virginica')],'bo',markersize=10)
plt.plot(train.PetalLengthCm[(train['Species']=='Iris-virginica')],train.PetalWidthCm[(train['Species']=='Iris-virginica')],'bo',markersize=10)

plt.show()

# %%
sl=df[['SepalLengthCm']]
sw=df[['SepalWidthCm']]
pl=df[['PetalWidthCm']]
pw=df[['PetalWidthCm']]
sl.plot.kde()
sw.plot.kde()
pl.plot.kde()
pw.plot.kde()

# %%
train_x=train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
train_y=train.Species

test_x=test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
test_y=test.Species

# %%
#Decision tree
from sklearn import tree
from sklearn.metrics import confusion_matrix
clf = tree.DecisionTreeClassifier()
clf=clf.fit(train_x,train_y)
clf.predict_proba(test_x)
clf.predict(test_x)
clf.score(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],df.Species)
confusion_matrix(clf.predict(test_x),test_y)
# Out:
# array([[17,  0,  0],
#        [ 0, 11,  1],
#        [ 0,  3, 13]])

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(train_x,train_y)
neigh.predict(test_x)
neigh.predict_proba(test_x)
neigh.score(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],df.Species)
confusion_matrix(neigh.predict(test_x),test_y)
# Out:
# array([[17,  0,  0],
#        [ 0, 13,  1],
#        [ 0,  1, 13]])

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df[df.SepalLengthCm<5.1]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 22    23            4.6           3.6            1.0           0.2
# 24    25            4.8           3.4            1.9           0.2
# ...

# %%
df.boxplot(column=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

# %%
df[df.SepalLengthCm>7.5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 105  106            7.6           3.0            6.6           2.1
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
#
#             Species
# 105  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# 122  Iris-virginica
# 131  Iris-virginica
# 135  Iris-virginica

# %%
df1 = df.drop(columns='Species')
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
#K Means
from sklearn.model_selection import train_test_split
train,test = train_test_split(df1,test_size=0.3,random_state=3)
train_x=train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
train_y=train.Species

test_x=test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
test_y=test.Species

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,random_state=0).fit(train_x)
kmeans.predict(test_x)
# Out:
# array([1, 1, 1, 1, 1, 0, 2, 1, 0, 2, 2, 1, 2, 2, 0, 1, 2, 0, 2, 1, 2, 0,
#        0, 2, 1, 0, 0, 2, 2, 2, 1, 1, 0, 2, 1, 1, 0, 1, 0, 2, 0, 2, 1, 1,
#        2], dtype=int32)
